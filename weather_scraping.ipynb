# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Daily, Point
import geopandas as gpd

# %%
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31)
amsterdam = Point(lat=52.373882, lon=4.891711)

# Get daily data
data = Daily(amsterdam, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
polygons = gpd.read_file('agri_46.geojson')
for name, geom in polygons.iterrows():
    print(geom[0] == name)
    print(geom[1].centroid.x)
# Out:
# False
# 7.097669751690758
# False
# 5.701584693106557
# False
# 6.46955756747646
# False
# 5.807388153091078
# False
# 4.972182044518971
# False
# 5.752615435094752
# False
# 3.521186871583042
# False
# 4.576534316334265
# False
# 5.194589646060991
# False
# 5.291541819211383
# False
# 4.425976223662009
# False
# 5.686480282918539
# False
# 5.004795000659783
# False
# 6.5091667328863645
# False
# 5.3008967292802
# False
# 4.911383251134239
# False
# 4.786356623474521
# False
# 5.112447156616753
# False
# 5.752493470961601
# False
# 5.696811710249215
# False
# 5.409456893220832
# False
# 5.488854857356628
# False
# 4.879079047644227
# False
# 5.32993237873534
# False
# 6.402750084930965
# False
# 6.2348654133020425
# False
# 5.847260216201686
# False
# 5.852279359441434
# False
# 5.737540359030231
# False
# 5.646206453319355
# False
# 5.559191893730903
# False
# 5.872107236373173
# False
# 6.696718502584121
# False
# 6.883575813371488
# False
# 6.476719437191546
# False
# ...

# %%
polygons["centroid"] = polygons.geometry.centroid

# %%
for index, centroid in enumerate(polygons['centroid']):
    print(polygons['name'][index])
# Out:
# winschoten
# sneek
# assen
# arnhem
# tilburg
# maastricht
# middelburg
# zoetermeer
# utrecht
# eindhoven
# roosendaal
# emmeloord
# wieringswerf
# hoogeveen
# geldermalsen
# oudekerk
# alkmaar
# hoorn
# dronten
# biddinghuizen
# leersum
# oss
# woerden
# almere
# lochem
# raalte
# luttelgeest
# ens
# nagele
# urk
# franeker
# leeuwarden
# almelo
# oldenzaal
# nijverdal
# zuthpen
# groenlo
# helmond
# schijndel
# almkerk
# schoonhoven
# montfoort
# voorschoten
# delft
# zuidland
# middelharnis

# %%
start = datetime(2023, 1, 1)
end = datetime(2023, 1, 15)
point = Point(polygons.centroid[0].y, polygons.centroid[0].x)

# Get daily data
data = Daily(point, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()
# Out:
# ...
#
# ...
