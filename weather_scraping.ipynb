# %%
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Daily, Point

# %%
start = datetime(2018, 1, 1)
end = datetime(2018, 12, 31)
amsterdam = Point(lat=52.373882, lon=4.891711)

# Get daily data
data = Daily(amsterdam, start, end)
data = data.fetch()

# Plot line chart including average, minimum and maximum temperature
data.plot(y=['tavg', 'tmin', 'tmax'])
plt.show()

# %%
data
# Out:
#             tavg  tmin  tmax  prcp  snow   wdir  wspd  wpgt    pres  tsun
# time
# 2018-01-01   7.0   5.9   8.2   NaN   NaN  221.0  28.2   NaN   997.2   NaN
# 2018-01-02   6.4   4.2   8.4   NaN   NaN  233.0  23.3   NaN  1005.3   NaN
# 2018-01-03   8.6   6.1  10.6   NaN   NaN  247.0  48.6   NaN   989.3   NaN
# 2018-01-04   8.2   7.0  10.8   NaN   NaN  232.0  31.5   NaN   992.9   NaN
# 2018-01-05   6.2   4.0   7.9   NaN   NaN  214.0  21.3   NaN   994.6   NaN
# ...          ...   ...   ...   ...   ...    ...   ...   ...     ...   ...
# 2018-12-27   2.9  -0.3   5.1   0.0   NaN  174.0   8.3  22.0  1026.7   NaN
# 2018-12-28   4.7   0.4   6.8   0.0   NaN  185.0   8.0  22.0  1028.4   NaN
# 2018-12-29   8.5   6.7  10.7   0.1   NaN  240.0  25.8  61.0  1028.8   NaN
# 2018-12-30   8.7   7.2   9.5   0.1   NaN  279.0  18.2  50.0  1032.0   NaN
# 2018-12-31   9.1   8.4  10.5   0.0   NaN  279.0  15.5  29.6  1033.1   NaN
#
# [365 rows x 10 columns]
